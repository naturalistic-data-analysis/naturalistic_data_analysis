# %%
# %matplotlib inline

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bids import BIDSLayout, BIDSValidator

base_dir = '/Users/lukechang/Dropbox/Depression_Autoencoder/'

# %%
data_dir = '/Volumes/Engram/Data/ds002345-download'
layout = BIDSLayout(data_dir, derivatives=True)
layout
# Out:
# /Users/lukechang/anaconda3/lib/python3.7/site-packages/bids/layout/layout.py:774: UserWarning: Derivative indexing was requested, but no valid datasets were found in the specified locations (['/Volumes/Engram/Data/ds002345-download/derivatives']). Note that all BIDS-Derivatives datasets must meet all the requirements for BIDS-Raw datasets (a common problem is to fail to include a dataset_description.json file in derivatives datasets).
#   "datasets).".format(paths))
# BIDS Layout: .../Engram/Data/ds002345-download | Subjects: 315 | Sessions: 0 | Runs: 184

# %%
layout.get_task()
# Out:
# ---------------------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-7-1f256ca75d2b> in <module>
# ----> 1 layout.get_task()
#
# ~/anaconda3/lib/python3.7/site-packages/bids/layout/layout.py in get(self, return_type, target, scope, regex_search, absolute_paths, drop_invalid_filters, **filters)
#     968
#     969             if return_type == 'id':
# --> 970                 results = list(set([x.entities[target] for x in results]))
#     971                 results = natural_sort(results)
#     972
#
# TypeError: unhashable type: 'dict'

# %%
layout.entities['task']
# Out:
# ---------------------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-41-e49f2f517365> in <module>
# ----> 1 layout.entities['task'].count()
#       2
#
# ~/anaconda3/lib/python3.7/site-packages/bids/layout/models.py in count(self, files)
#     529             Count of unique values or files.
#     530         """
# --> 531         return len(self.files) if files else len(self.unique())
#     532
#     533     def _astype(self, val):
#
# ~/anaconda3/lib/python3.7/site-packages/bids/layout/models.py in unique(self)
#     513         """Return all unique values/levels for the current entity.
#     514         """
# --> 515         return list(set(self.files.values()))
#     516
#     517     def count(self, files=False):
#
# TypeError: unhashable type: 'dict'

# %%
layout.get_subjects()
# Out:
# ['001',
#  '002',
#  '003',
#  '004',
#  '005',
#  '006',
#  '007',
#  '008',
#  '009',
#  '010',
#  '011',
#  '012',
#  '013',
#  '014',
#  '015',
#  '016',
#  '017',
#  '018',
#  '019',
#  '020',
#  '021',
#  '022',
#  '023',
#  '024',
#  '025',
#  '026',
#  '027',
#  '028',
#  '029',
#  '030',
#  '031',
#  '032',
#  '033',
#  '034',
#  '035',
#  '036',
#  '037',
#  '038',
#  '039',
#  '040',
#  '041',
#  '042',
#  '043',
#  '044',
#  '045',
#  '046',
#  '047',
#  '048',
#  '049',
#  '050',
#  '051',
#  '052',
#  '053',
#  '054',
#  '055',
#  '056',
#  '057',
#  '058',
#  '059',
#  '060',
#  '061',
#  '062',
#  '063',
#  '064',
#  '065',
#  '066',
#  '067',
#  '068',
#  '069',
#  '070',
#  '071',
#  '072',
#  '073',
#  '074',
#  '075',
#  '076',
#  '077',
#  '078',
#  '079',
#  '080',
#  '081',
#  '082',
#  '083',
#  '084',
#  '085',
#  '086',
#  '087',
#  '088',
#  '089',
#  '090',
#  '091',
#  '092',
#  '093',
#  '094',
#  '095',
#  '096',
#  '097',
#  '098',
#  '099',
#  '100',
# ...

# %%
layout.get_tasks()
# Out:
# ---------------------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-45-be949d647223> in <module>
# ----> 1 layout.get_tasks()
#
# ~/anaconda3/lib/python3.7/site-packages/bids/layout/layout.py in get(self, return_type, target, scope, regex_search, absolute_paths, drop_invalid_filters, **filters)
#     968
#     969             if return_type == 'id':
# --> 970                 results = list(set([x.entities[target] for x in results]))
#     971                 results = natural_sort(results)
#     972
#
# TypeError: unhashable type: 'dict'

# %%
layout.get(target='task', suffix='bold')
# Out:
# [<BIDSJSONFile filename='/Volumes/Engram/Data/ds002345-download/sub-001/func/sub-001_task-pieman_run-1_bold.json'>,
#  <BIDSImageFile filename='/Volumes/Engram/Data/ds002345-download/sub-001/func/sub-001_task-pieman_run-1_bold.nii.gz'>,
#  <BIDSJSONFile filename='/Volumes/Engram/Data/ds002345-download/sub-001/func/sub-001_task-pieman_run-2_bold.json'>,
#  <BIDSImageFile filename='/Volumes/Engram/Data/ds002345-download/sub-001/func/sub-001_task-pieman_run-2_bold.nii.gz'>,
#  <BIDSJSONFile filename='/Volumes/Engram/Data/ds002345-download/sub-001/func/sub-001_task-tunnel_bold.json'>,
#  <BIDSImageFile filename='/Volumes/Engram/Data/ds002345-download/sub-001/func/sub-001_task-tunnel_bold.nii.gz'>,
#  <BIDSJSONFile filename='/Volumes/Engram/Data/ds002345-download/sub-002/func/sub-002_task-pieman_run-1_bold.json'>,
#  <BIDSImageFile filename='/Volumes/Engram/Data/ds002345-download/sub-002/func/sub-002_task-pieman_run-1_bold.nii.gz'>,
# ...

# %%
df = layout.to_df()
df['task']
# Out:
# 0                                                     NaN
# 1                                                     NaN
# 2       {'Description': 'tasks (story stimuli) collect...
# 3                                                     NaN
# 4                                                     NaN
#                               ...
# 3786                                            piemanpni
# 3787                                                  NaN
# 3788                                                  NaN
# 3789                                                  NaN
# 3790                                                  NaN
# Name: task, Length: 3791, dtype: object

# %%
df_reduc = df.loc[(df['extension']=='tsv') & (df['suffix']=='events')]
df_reduc['task'].unique()
# Out:
# array(['pieman', 'tunnel', 'notthefall', 'slumlordreach', 'lucy',
#        'milkyway', 'prettymouth', 'schema', 'shapesphysical',
#        'shapessocial', '21styear', 'merlin', 'sherlock', 'black', 'bronx',
#        'forgot', 'piemanpni'], dtype=object)

# %%
df.loc[(df['task']=='pieman')&(df['extension']=='nii.gz')]
# Out:
# entity                                               path datatype extension  \
# 6       /Volumes/Engram/Data/ds002345-download/sub-001...     func    nii.gz
# 9       /Volumes/Engram/Data/ds002345-download/sub-001...     func    nii.gz
# 19      /Volumes/Engram/Data/ds002345-download/sub-002...     func    nii.gz
# 22      /Volumes/Engram/Data/ds002345-download/sub-002...     func    nii.gz
# 29      /Volumes/Engram/Data/ds002345-download/sub-003...     func    nii.gz
# ..                                                    ...      ...       ...
# 831     /Volumes/Engram/Data/ds002345-download/sub-078...     func    nii.gz
# 841     /Volumes/Engram/Data/ds002345-download/sub-079...     func    nii.gz
# 851     /Volumes/Engram/Data/ds002345-download/sub-080...     func    nii.gz
# 861     /Volumes/Engram/Data/ds002345-download/sub-081...     func    nii.gz
# 871     /Volumes/Engram/Data/ds002345-download/sub-082...     func    nii.gz
#
# entity  run scans subject suffix    task
# ...

# %%
layout.get_metadata.
# Out:
# <bound method BIDSLayout.get_metadata of BIDS Layout: .../Engram/Data/ds002345-download | Subjects: 315 | Sessions: 0 | Runs: 184>

# %%
layout.get(subject='sub-127')
# Out:
# []
